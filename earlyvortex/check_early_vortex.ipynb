# %%
import numpy as np
import apss_lib
import ppplot
import matplotlib.pyplot as mpl
# %matplotlib inline
# Out:
# 2020-04-21 07:52:50.037157

# %%
## 388
## 436
## 465 strange
## otherwise, gravity waves
soltab = range(1,401)
soltab = [388,436,465] #465 strange (wavy)
soltab = [388]

# %%
for solsol in soltab:
    try:
        data = apss_lib.getsol(solsol,var="PRE",distant=True)
        apss_lib.plotvar(data,code=["PRE"],mint=7,maxt=8,\
                     window=1000,perturbamp=0.7,lim=-0.3,\
                     mode="png",filename="earlyvortices_sol%i"%(solsol))
    except:
        pass
# Out:
# APSS_LIB: ---------- GETDATA ----------
# APSS_LIB: using existing local Python binary file: /home/aspiga/data/InSight/npy//ps_calib_0388_01.npy
# APSS_LIB: smoothresample done in 5 seconds

# %%
data = apss_lib.getsol(388,var="PRE",distant=True)
foo = apss_lib.plotvar(data,code=["PRE"],mint=7.7,maxt=7.9,\
                     window=1000,perturbamp=0.7,lim=-0.3)
foo = apss_lib.plotvar(data,code=["PRE"],mint=7.38,maxt=7.4,\
                     window=1000,perturbamp=0.7,lim=-0.3,timetype="LMST")
# Out:
# APSS_LIB: ---------- GETDATA ----------
# APSS_LIB: using existing local Python binary file: /home/aspiga/data/InSight/npy//ps_calib_0388_01.npy
# APSS_LIB: smoothresample done in 5 seconds
# APSS_LIB: smoothresample done in 5 seconds
